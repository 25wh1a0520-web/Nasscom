# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0520-web/Nasscom/blob/main/WRITING_AND_USING_FUNCTIONS_DAY1_WEEK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
    print("Hello! Welcome to Python Functions.")

greet()
# Out:
# Hello! Welcome to Python Functions.

# %%
def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
greet_user("Bob")
# Out:
# Hello, Alice!
# Hello, Bob!

# %%
def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()
greet_user("Ravi:")
# Out:
# Welcome, Guest!
# Welcome, Ravi:!

# %%
def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Alice", "bob", "Charlie")
# Out:
# Names passed: ('Alice', 'bob', 'Charlie')
# Hello Alice
# Hello bob
# Hello Charlie

# %%
def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")
# Out:
# User Info:
# name = Alice
# age = 25
# city = Delhi

# %%
def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="mumbai")
# Out:
# Args: (1, 2, 3)
# Kwargs: {'name': 'Ravi', 'city': 'mumbai'}

# %%
def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))
# Out:
# Square of 4: 16
